# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
n=2.7644464446444643
m=3.254095409540954
u=2
x_1 = [0,m]
x_3 = [0,n]
x_2 = [n,4.5]
p1 = [-0.97177481 , 2.95229421]
p8 = [0.50478385 , 0.14711596]
p9= [-0.60707218,  3.22098245]
def calc_y(x,p):
    x=np.array(x)
    p=np.array(p)
    y=p[0]*x + p[1]
    return y

# %%
x1 = [1.6639091, 1.25883665, 4.91867494, 1.66023615, 2.93737892, 1.60649894,
 0.06893099, 1.49847783, 2.81798447, 1.79432599, 3.11002516, 1.62578166,
 3.64986296, 3.01454626, 3.12570586, 3.91316601, 3.47601037, 2.81777499,
 0.4033991,  2.40551294, 1.35772895]
y1= -1 * np.array([ 1.33534926,  1.72898846,  0.62998363,  1.33891854,  0.09782337,  1.39113901,
  2.88530881,  1.4961112,   0.21384789,  1.20861341, -0.0699499,   1.37240055,
 -0.01049216,  0.02283409, -0.08518801,  0.12241896, -0.09825014,  0.21405145,
  2.56028113,  0.61467733,  1.63288742])
x = [1.6639091 , 1.25883665, 2.93737892, 1.60649894, 0.06893099, 1.49847783, 2.81798447, 1.79432599, 1.62578166, 3.64986296, 3.01454626, 3.12570586, 3.91316601, 3.47601037, 1.35772895, 3.9]
y = -1 * np.array([ 1.29652311, 1.4272416, 0.18465298, 1.09691747, 3.13466883, 1.57139272, 0.38135704, 1.1742328, 1.17297363, 0.0514634, 0.16048154, 0.33280224, 0.31521813, 0.07978424,  1.42307145,0.07 ])


n=2.7644464446444643
m=3.254095409540954
u=2
x_1 = [0,m]
x_3 = [0,n]
x_2 = [n,4.5]
p1 = [-0.97177481 , 2.95229421]
p8 = [0.50478385 , 0.14711596]
p9= [-0.60707218,  3.22098245]
def calc_y(x,p):
    x=np.array(x)
    p=np.array(p)
    y=p[0]*x + p[1]
    return y


plt.rcParams["font.weight"] = "bold"
plt.rcParams["font.size"] = 30
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams['lines.markersize'] = 15
plt.rc('lines', linewidth=10)
plt.rcParams['axes.linewidth'] = 3
fig = plt.figure(figsize=(12*1.618,12))

plt.plot(x_1,-1*calc_y(x_1,p1),label = '*O --> *ONN')
plt.plot(x_3,-1*(calc_y(x_3,p9)-u),label = '*O --> *OOH')
plt.plot(x_2,-1*(calc_y(x_2,p8)-u),label = '*OH --> *O',color='silver')
font=24
plt.scatter(x,y, marker='D',c='black',zorder=2)
#plt.Rectangle((0,-3.5),4.5,4,color='black',linewidth=10,zorder=-1)
plt.xlim(0,4.5)
plt.xlabel('$E_N$  (eV)', fontsize=40)
plt.ylabel('$- \Delta G $ (eV)', fontsize=40)
plt.text(0.12,-3.2,'ReO$_2$',fontsize=font,fontweight='bold')
plt.text(0.8,-1.48,'IrRuO$_2$',fontsize=font,fontweight='bold')
plt.text(1.4,-1.48,'TiRuO$_2$',fontsize=font,fontweight='bold')
plt.text(1.55,-1.62,'ReRuO$_2$',fontsize=font,fontweight='bold')
plt.text(1.13,-1.11,'PtRuO$_2$',fontsize=font,fontweight='bold')
plt.text(1.28,-1.25,'RuO$_2$',fontsize=font,fontweight='bold')
plt.text(1.84,-1.22,'RhRuO$_2$',fontsize=font,fontweight='bold')
plt.text(1.7,-1.35,'IrO$_2$',fontsize=font,fontweight='bold')
plt.text(2.47,-0.47,'RhO$_2$',fontsize=font,fontweight='bold')
plt.text(2.62,-0.22,'PtO$_2$',fontsize=font,fontweight='bold')
plt.text(3.18,-0.4,'RuRhO$_2$',fontsize=font,fontweight='bold')
plt.text(3.05,-0.24,'RuPtO$_2$',fontsize=font,fontweight='bold')
plt.text(3.0,-0.1,'TiPdO$_2$',fontsize=font,fontweight='bold')
plt.text(3.2,-0.,'RuPdO$_2$',fontsize=font,fontweight='bold')
plt.text(3.95,-0.36,'TiO$_2$',fontsize=font,fontweight='bold')
plt.text(3.95,-0.1,'PdO$_2$',fontsize=font,fontweight='bold')
plt.legend()
plt.savefig('vol.pdf')

# %%
from ase.io import read
import numpy as np
from common import get_omega,greplines,fed
import os
import matplotlib.pyplot as plt

plt.rcParams["font.weight"] = "bold"
plt.rcParams["font.size"] = 30
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams['lines.markersize'] = 15
plt.rc('lines', linewidth=8)
fig = plt.figure(figsize=(12*1.618,12))

u=2.0
plt.style.use('tableau-colorblind10')

lab=['$CO_2+NO_3^-$','$CO*+NO*$','$CONO*$','$CONOH*$','$CON*$','$CONH*$','$CONH_2$*','$CONH_2NO$*','$CONH_2NH_2$']
lab_E=[0.0,-4.333,-4.632,-5.079,-8.170,-7.225,-7.578,-8.710,-12.40291339]
N2OR=[(0.0,'min'),(-0.48,'min'),(0.906-u,'min'),(2.967-2*u,'min'),(-0.089-2*u,'min'),(1.938-4*u,'min'),(4.468-6*u,'min'),(12.430-10*u,'min')]

N2OR2=[(0.0,'min'),(1.296,'min'),(3.298-u,'min'),(4.42-2*u,'min'),(2.613-2*u,'min'),(4.814-4*u,'min'),(7.932-6*u,'min'),(12.430-10*u,'min')]

N2OR1=[(0.0,'min'),(0.286,'min'),(2.272-u,'min'),(3.812-2*u,'min'),(1.811-2*u,'min'),(3.43-4*u,'min'),(6.128-6*u,'min'),(12.430-10*u,'min')]

NNOs=[(0.0,'min'),(1.296,'min'),(2.416-u,'min'),(3.513-2*u,'min')]
OER=[(0.0,'min'),(1.9-u,'min'),(2.777-2*u,'min'),(3.798-3*u,'min'),(4.92-4*u,'min') ]
fed(path=N2OR,label='$TiPdO_2$',fig=fig)
fed(path=N2OR1,label='$RuRhO_2$',fig=fig)
fed(path=N2OR2,label='$IrO_2$',fig=fig)
plt.legend()
plt.xlabel('Reaction coordinate')
plt.ylabel('$\Delta G$  (eV)')
plt.ylim(-8,2)
plt.xlim(-0.2,22.2)
plt.savefig("mulpathway.png", format = 'png', dpi=300)
# plt.show()

# %%
from ase.io import read
import numpy as np
from common import get_omega,greplines,fed
import os
import matplotlib.pyplot as plt

#plt.figure(figsize=(4*1.618,4))
plt.rcParams["font.weight"] = "bold"
plt.rcParams["font.size"] = 30
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams['lines.markersize'] = 15
plt.rc('lines', linewidth=8)
fig = plt.figure(figsize=(12*1.618,12))

plt.style.use('tableau-colorblind10')

u=2.0

bar = 0.98369
#lab=['$CO_2+NO_3^-$','$CO*+NO*$','$CONO*$','$CONOH*$','$CON*$','$CONH*$','$CONH_2$*','$CONH_2NO$*','$CONH_2NH_2$']
lab_E=[0.0,-4.333,-4.632,-5.079,-8.170,-7.225,-7.578,-8.710,-12.40291339]
#N2OR=[(0.0,'min'),(1.296,'min'),(3.196-u,'min'),(3.907-2*u,'min'),(4.229-3*u,'min'),(4.814-4*u,'min'),(7.932-6*u,'min'),(10.186-8*u,'min'),(12.430-10*u,'min')]

N2OR=[(0.0,'min'),(bar,'ts'),(-0.48,'min'),(0.906-u,'min'),(2.967-2*u,'min'),(2.967-2*u,'ts'),(-0.089-2*u,'min'),(1.938-4*u,'min'),(4.468-6*u,'min'),(12.430-10*u,'min')]
NOER=[(0.0,'min'),(bar,'ts'),(-0.48,'min'),(0.906-u,'min'),(2.967-2*u,'min'),(6.711-4*u,'min')]
NO2ER=[(0.0,'min'),(bar,'ts'),(-0.48,'min'),(0.906-u,'min'),(2.967-2*u,'min'),(2.967-2*u,'ts'),(-0.089-2*u,'min'),(1.938-4*u,'min'),(10.894-8*u,'min')]
NNOs=[(0.0,'min'),(bar,'ts'),(-0.48,'min'),(3.513-2*u,'min')]
OER=[(0.0,'min'),(0.781-u,'min'),(4.92-4*u,'min') ]
#formamide_path=[(0.0,'min'),(-4.333,'min'),(-4.333+0.01,'ts'),(-4.632,'min'),(-5.079,'min'),(-8.170,'min'),(-7.225,'min'),(-7.578,'min'),(-6.072935282,'min')]
#NH3_path=[(0.0,'min'),(-4.333,'min'),(-6.38468038,'min')]
#fig = plt.figure(figsize=(8*1.618,8))
fed(path=OER,label='OER',fig=fig)
fed(path=NOER,label='$N_2$  -->  $2NO$',fig=fig)
fed(path=NO2ER,label='$N_2$  -->  $2NO_2$',fig=fig)
fed(path=NNOs,label='$N_2$  -->  $N_2O$',fig=fig)
fed(path=N2OR,label='$N_2OR$',fig=fig)
plt.legend()
#plt.plot(x,y1,label='Nitrate adsorption energy')
#plt.plot(x,y2, label='$CO_2$ adsorption energy')
#plt.plot(x,y3,'k--')
plt.xlabel('Reaction coordinate')
plt.ylabel('$\Delta G$  (eV)')
plt.ylim(-8,2)
plt.xlim(-0.2,22.2)
#plt.text(0,0+0.02,'CO*+NO*', color='steelblue')
#plt.text(3.1,-0.3+0.02,'CONO*', color='steelblue')
#for k in range(0,len(lab)):
 #   plt.text(k*3,lab_E[k]+0.08,lab[k], color='black')
 #plt.text(21,-6.072935282+0.08,'$HCONH_2$', color='steelblue')
#plt.text(0,0-0.06,'CONH2*+NO*', color='darkorange')
#plt.text(3.1,-1.133+0.02,'CONH2NO*', color='darkorange')
#plt.gca().invert_xaxis()
#plt.legend()
plt.savefig("new_pathway.png", format = 'png', dpi=300)
plt.show()

# %%
x3= [1.6639091, 1.25883665, 2.93737892, 1.60649894, 0.06893099,
 1.49847783, 2.81798447, 1.79432599, 1.62578166, 3.64986296, 3.01454626,
 3.12570586, 5.11853445, 3.47601037, 1.35772895, 3.67998604, 3.91]
y3=[ 1.29352311, 1.4242416, 0.18165298,  1.09391747,  3.13166883,
  1.56839272,  0.37835704,  1.1712328,   1.16997363, -0.5019295,   0.15748154,
  0.32980224, -1.33616351, -0.45129325,  1.42007145, -0.4258407, -1.32 ]
plt.rcParams["font.weight"] = "bold"
plt.rcParams["font.size"] = 30
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams['lines.markersize'] = 15
plt.rc('lines', linewidth=10)
plt.rcParams['axes.linewidth'] = 3
fig = plt.figure(figsize=(12*1.618,12))
xx=[0,4.2]
px=[-0.85424572, 2.74969337]
x__ = [0.0,0,4.2]
y__ = [0,0,0]
plt.plot(xx,calc_y(xx,px),label = '*O --> *ONN',zorder=2)
plt.plot(x__,y__,'--',zorder=1)
plt.scatter(x3,y3, marker='D',c='black',zorder=3)

#plt.plot(x_3,-1*(calc_y(x_3,p9)-u),label = '*O --> *OOH')
#plt.plot(x_2,-1*(calc_y(x_2,p8)-u),label = '*OH --> *O')
font=24

#plt.Rectangle((0,-3.5),4.5,4,color='black',linewidth=10,zorder=-1)
plt.xlim(0,4.2)
plt.xlabel('$E_N$  (eV)', fontsize=40)
plt.ylabel('$ \Delta G_{*ONN} - G_{*O} $ (eV)', fontsize=40)

plt.text(0.12,3.06,'ReO$_2$',fontsize=font,fontweight='bold')
plt.text(0.85,1.36,'IrRuO$_2$',fontsize=font,fontweight='bold')
plt.text(1.4,1.38,'TiRuO$_2$',fontsize=font,fontweight='bold')
plt.text(1.55,1.52,'ReRuO$_2$',fontsize=font,fontweight='bold')
plt.text(1.13,1.01,'PtRuO$_2$',fontsize=font,fontweight='bold')
plt.text(1.28,1.15,'RuO$_2$',fontsize=font,fontweight='bold')
plt.text(1.84,1.1,'RhRuO$_2$',fontsize=font,fontweight='bold')
plt.text(1.7,1.25,'IrO$_2$',fontsize=font,fontweight='bold')
plt.text(2.47,0.37,'RhO$_2$',fontsize=font,fontweight='bold')
plt.text(2.62,0.12,'PtO$_2$',fontsize=font,fontweight='bold')
plt.text(3.18,0.3,'RuRhO$_2$',fontsize=font,fontweight='bold')
plt.text(3.05,0.12,'RuPtO$_2$',fontsize=font,fontweight='bold')
plt.text(3.05,-0.5,'TiPdO$_2$',fontsize=font,fontweight='bold')
plt.text(3.7,-0.5,'RuPdO$_2$',fontsize=font,fontweight='bold')
plt.text(3.95,-1.38,'TiO$_2$',fontsize=font,fontweight='bold')
#plt.savefig("act_scaling.png", format = 'png', dpi=300)
plt.savefig('act_scaling.pdf')

# %%
x4= [1.6639091,  1.25883665, 1.66023615, 2.93737892, 1.60649894, 0.06893099,
 1.49847783, 2.81798447, 1.79432599, 3.11002516, 1.62578166, 3.64986296,
 3.01454626, 3.12570586, 3.92, 3.47601037, 1.35772895, 3.67998604]
y4=[1.38488916, 1.10323671, 1.15080789, 1.99559133, 1.18714121, 0.54431885,
 1.24150592, 1.69556306, 1.0771651,  1.53998978, 1.14049074, 2.3144634,
 2.18677869, 1.73519635, 2.57821813, 2.34278424, 1.15340078, 2.12609097]
plt.rcParams["font.weight"] = "bold"
plt.rcParams["font.size"] = 30
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams['lines.markersize'] = 15
plt.rc('lines', linewidth=10)
plt.rcParams['axes.linewidth'] = 3
fig = plt.figure(figsize=(12*1.618,12))

plt.scatter(x4,y4,marker='D',c='black')
x__ = [-0.1,0,4.2]
z = np.polyfit(x4,y4, 1)
p = np.poly1d(z)
print(p.c)
plt.plot(x__ ,p(x__))
plt.xlabel('$\Delta E_{N}$  (eV)')
plt.ylabel('$\Delta E_{O} - \Delta E_{OH} $  (eV)')
plt.xlim(-0.1,4.2)
plt.savefig("O-OHvsN.png", format = 'png', dpi=300)
# Out:
# [0.4952727  0.42024024]

# %%
from ase.io import read
import numpy as np
from common import get_omega,greplines,fed
import os
import matplotlib.pyplot as plt
import seaborn as sns
#x= np.linspace(-1.5,1,2)
#y=0.7247675*x + 0.94357862
fig = plt.figure(figsize=(12*1.618,12))
#print(y)
#plt.plot(y,x)
x= [0.024024509999988286, 0.330519440000002, 0.5240810099999877, 0.11282755000000444, 
    0.5240810099999877, 0.5240810099999877, 0.6505660700000093, -0.7112466200000127, 
    0.1387598600000346, 0.787688150000021, 0.666470840000001, 1.0287009100000106, 
    0.6072369999999823, 0.9638732599999984, 0.41103776999999164, 0.8129770699999725, 
    1.6812225700000298, 0.9429690599999803, 0.5240810099999877, 0.5240810099999877, 
    0.5240810099999877, 0.2916748200000101, 1.0541158199999772, 0.5240810099999877]
y= [-0.749490900000005, -0.30380841000000913, -0.2937066899999863, -0.6113068699999573,
    -0.2937066899999863, -0.2937066899999863, -0.018763349999993295, -1.2, -0.37802362999996575,
    -0.20938560999999112, -0.040836549999987426, 0.3354331199999834, -0.135405530000007, 
    0.07225013999997287, -0.04988554999999195, -0.18701238999999958, 0.12579237000000631, 
    -0.014561730000018258, -0.2937066899999863, -0.2937066899999863, -0.2937066899999863, 
    -0.09986690999999581, 0.005854710000001262, -0.2937066899999863]

y_=1.25874969*np.array([-1.5,0.5]) + 0.94330941
#plt.plot([-1.5,0.5],y_)
#plt.scatter(y,x)
Ads_Ex = np.array(x) + 0.36
Ads_Ey = np.array(y) + 0.212
m,n=1000,1000
z = np.polyfit(Ads_Ey,Ads_Ex, 1)
p = np.poly1d(z)
print(p.c)
x__ = np.linspace(-1.5,1,m)
u_ = np.linspace(0,2,n)
s = 20

def calc_cov(n2,oh):
    T=298.15
    g1 = n2
    g2 = oh
    F=96485.3321
    R=8.314
    K1 = np.exp(-g1*F/(R*T))
    K2=np.exp(-g2*F/(R*T))
    O1=K1/(1+K1+K2)
    return O1

arr2_ = np.zeros([m,n])
for i in range(0,m):
    for j in range(0,n):
        x = x__[i]
        u = u_[j]
        y = p(x) - u
        arr2_[j,i]=calc_cov(x,y)




def calc_cov1(n2,oh):
    T=298.15
    g1 = n2
    g2 = oh
    F=96485.3321
    R=8.314
    K1 = np.exp(-g1*F/(R*T))
    K2=np.exp(-g2*F/(R*T))
    O2=K2/(1+K1+K2)
    return O2

arr1_ = np.zeros([m,n])
for i in range(0,m):
    for j in range(0,n):
        x = x__[i]
        u = u_[j]
        y = p(x) - u
        arr1_[j,i]=calc_cov1(x,y)

arr_ = np.zeros([m,n])
for i in range(0,m):
    for j in range(0,n):
        if arr2_[j,i] > arr1_[j,i]:
            arr_[j,i]=arr2_[j,i]
        else:
            arr_[j,i]=-1 * arr1_[j,i]

#print('arrrrrr is', arr_)

#x =x.reshape(-1,1)
#u =u.reshape(-1,1)
X,Y=np.meshgrid(x__, u_)
def heatmap2d(arr):
    plt.rcParams["font.weight"] = "bold"
    plt.rcParams["font.size"] = 30
    plt.rcParams["axes.labelweight"] = "bold"
    plt.rcParams['lines.markersize'] = 15
    plt.rc('lines', linewidth=10)
    plt.rcParams['axes.linewidth'] = 3
    fig = plt.figure(figsize=(12*1.618,12))

    #plt.imshow(arr, cmap='viridis')
    plt.contourf(X,Y,arr, 100, cmap='RdYlBu',vmin=-1,vmax=1)
    #plt.contourf(X,Y,arr1, 100, cmap='RdYlBu',vmin=0,vmax=1)
    #sns.heatmap(arr_, xticklabels=x__)
    #plt.colorbar(label = '$N_2$ Coverage',boundaries=0-1, ticks =[0.0,0.5,1.0])
    #plt.xticks([])
    #plt.yticks([])
    
    y_=0.25874969*np.array([-1.5,0]) + 0.94330941
    y__=1.25874969*np.array([0,1.0]) + 0.94330941
    plt.plot([-1.5,0.0],y_,'--',color='black')
    plt.plot([0.0,1.0],y__,'--',color='black')
    plt.plot([0,0],[0,0.94330941],'--',color='black')
    plt.xlim(-1.5,1.0)
    plt.ylim(0,2.0)
    plt.yticks([0.5,1.0,1.5,2.0])
    
    plt.xlabel('$\Delta G_{N_2}$  (eV)')
    plt.ylabel('Potential  (V vs RHE)')
    plt.savefig('heat.pdf')
    plt.show()
    
#print('arr1 value is ',arr_, 'arr value is ',arr1_)
#print('X value is ',X,'Y value is ',Y)
heatmap2d(arr_)
# Out:
# [1.25874969 0.94330941]

# %%
x1 = [1.6639091, 1.25883665, 4.91867494, 1.66023615, 2.93737892, 1.60649894,
 0.06893099, 1.49847783, 2.81798447, 1.79432599, 3.11002516, 1.62578166,
 3.64986296, 3.01454626, 3.12570586, 3.91316601, 3.47601037, 2.81777499,
 0.4033991,  2.40551294, 1.35772895]
y1= -1 * np.array([ 1.33534926,  1.72898846,  0.62998363,  1.33891854,  0.09782337,  1.39113901,
  2.88530881,  1.4961112,   0.21384789,  1.20861341, -0.0699499,   1.37240055,
 -0.01049216,  0.02283409, -0.08518801,  0.12241896, -0.09825014,  0.21405145,
  2.56028113,  0.61467733,  1.63288742])
x = [1.6639091 , 1.25883665, 2.93737892, 1.60649894, 0.06893099, 1.49847783, 2.81798447, 
     1.79432599, 1.62578166, 3.64986296, 3.01454626, 3.12570586, 3.91316601, 3.47601037, 
     1.35772895, 3.9]
y = -1 * np.array([ 1.98655048, 2.23867588, 1.73259133+0, 2.07113716, 3.38623732+0, 2.25760045, 
                   1.43256306+0, 2.299924, 2.20627066, 0.0514634+2, 1.92377869+0, 1.47219635+0, 
                   0.31521813+2, 0.07978424+2,  2.25570765,0.07+2 ])


n=2.7644464446444643
m=3.254095409540954
u=2
x_1 = [0,4.5]
x_3 = [0,n]
x_2 = [n,4.5]
p1 = [-0.97177481 , 2.95229421]
p8 = [0.50478385 , 0.14711596]
p9= [-0.60707218,  3.22098245]
def calc_y(x,p):
    x=np.array(x)
    p=np.array(p)
    y=p[0]*x + p[1]
    return y


plt.rcParams["font.weight"] = "bold"
plt.rcParams["font.size"] = 30
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams['lines.markersize'] = 15
plt.rc('lines', linewidth=10)
plt.rcParams['axes.linewidth'] = 3
fig = plt.figure(figsize=(12*1.618,12))

plt.plot(x_1,-1*calc_y(x_1,p1),label = '*O --> *ONN')
plt.plot(x_3,-1*(calc_y(x_3,p9)),label = '*O --> *OOH')
plt.plot(x_2,-1*(calc_y(x_2,p8)),label = '*OH --> *O',color='silver')
font=24
plt.scatter(x,y, marker='D',c='black',zorder=2)
#plt.Rectangle((0,-3.5),4.5,4,color='black',linewidth=10,zorder=-1)
plt.xlim(0,4.5)
plt.ylim(-3.49,0.6)
plt.xlabel('$E_N$  (eV)', fontsize=40)
plt.ylabel('$- \Delta G $ (eV)', fontsize=40)
plt.text(0.12,-3.2-0.25,'ReO$_2$',fontsize=font,fontweight='bold')
plt.text(0.82,-2.3,'IrRuO$_2$',fontsize=font,fontweight='bold')
plt.text(1.4-0.45,-2.5,'TiRuO$_2$',fontsize=font,fontweight='bold')
plt.text(1.55-0.5,-2.15,'ReRuO$_2$',fontsize=font,fontweight='bold')
plt.text(1.13,-1.90,'PtRuO$_2$',fontsize=font,fontweight='bold')
plt.text(1.28+0.4,-2.2,'RuO$_2$',fontsize=font,fontweight='bold')
plt.text(1.84,-2.4,'RhRuO$_2$',fontsize=font,fontweight='bold')
plt.text(1.7,-2.0,'IrO$_2$',fontsize=font,fontweight='bold')
plt.text(2.47,-1.5,'RhO$_2$',fontsize=font,fontweight='bold')
plt.text(2.62,-1.8,'PtO$_2$',fontsize=font,fontweight='bold')
plt.text(3.18,-1.55,'RuRhO$_2$',fontsize=font,fontweight='bold')
plt.text(3.05-0.5,-2.02,'RuPtO$_2$',fontsize=font,fontweight='bold')
plt.text(3.03,-0.15-2,'TiPdO$_2$',fontsize=font,fontweight='bold')
plt.text(3.2,0.03-2,'RuPdO$_2$',fontsize=font,fontweight='bold')
plt.text(3.95,-0.36-2,'TiO$_2$',fontsize=font,fontweight='bold')
plt.text(3.95,-0.1-2,'PdO$_2$',fontsize=font,fontweight='bold')
plt.legend()
plt.savefig('vol0v.pdf')

# %%
x1 = np.array([0.024024509999988286, 0.330519440000002, 0.11282755000000444, 0.5240810099999877, 
      0.5240810099999877, -0.7112466200000127, -0.7112466200000127, 0.1387598600000346, 0.787688150000021, 
      0.666470840000001, 1.0287009100000106, 0.6072369999999823, 0.9638732599999984, 0.41103776999999164, 
      0.787688150000021, 1.6812225700000298, 0.9429690599999803, 0.5240810099999877, 0.5240810099999877, 
      0.5240810099999877, 0.2916748200000101, 1.0541158199999772]) -2
y1 = [-0.749490900000005, -0.30380841000000913, -0.6113068699999573, -0.2937066899999863, 
      -0.2937066899999863, -1.2, -1.2, -0.37802362999996575, -0.20938560999999112, 
      -0.040836549999987426, 0.3354331199999834, -0.135405530000007, 0.07225013999997287, -0.04988554999999195, 
      -0.20938560999999112, 0.12579237000000631, -0.014561730000018258, -0.2937066899999863, 
      -0.2937066899999863, -0.2937066899999863, -0.09986690999999581, 0.005854710000001262]

plt.rcParams["font.weight"] = "bold"
plt.rcParams["font.size"] = 30
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams['lines.markersize'] = 15
plt.rc('lines', linewidth=10)
plt.rcParams['axes.linewidth'] = 3
fig = plt.figure(figsize=(12*1.618,12))
font=24

x2 = [-2.8,-2,-0.2]
y2 = [-1.04545252, -0.56597409, 0.51285237]
y__ = [0,0,0]

plt.plot(x2,y2)
plt.plot(x2,x2,'--')
plt.plot(x2,y__,'--')
plt.xlabel('$\Delta E_{OH}$  (eV)', fontsize=40)
plt.ylabel('$\Delta E_{N_2}$  (eV)', fontsize=40)
plt.scatter(x1,y1, marker='D',c='black',zorder=2)
plt.xlim(-2.8,-0.2)
plt.text(x1[2]+0.025, y1[2],'NbRuO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[10]+0.025, y1[10],'RuFeO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[6]+0.025,y1[6],'ReO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[1]-0.235,y1[1],'IrRuO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[20]-0.245, y1[20],'TiRuO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[7]-0.26,y1[7]-0.05,'ReRuO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[11]-0.18,y1[11]-0.05,'RuO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[9]-0.12,y1[9]+0.05,'RhRuO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[0]+0.025, y1[0]-0.05,'IrO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[8]-0.07,y1[8]-0.15,'RhO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[4]+0.025,y1[4]-0.05,'PtO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[13]-0.13,y1[13]+0.05,'RuPtO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[16]-0.1,y1[16]-0.15,'TiPdO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[12]+0.025,y1[12],'RuPdO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[15]-0.03,y1[15]+0.05,'TiO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[21]+0.025,y1[21]-0.05,'dimer_TiPdO$_2$',fontsize=font,fontweight='bold')
plt.savefig('OHNN_2.pdf')

# %%
x1 = np.array([0.024024509999988286, 0.330519440000002, 0.11282755000000444, 0.5240810099999877, 
      0.5240810099999877, -0.7112466200000127, -0.7112466200000127, 0.1387598600000346, 0.787688150000021, 
      0.666470840000001, 1.0287009100000106, 0.6072369999999823, 0.9638732599999984, 0.41103776999999164, 
      0.787688150000021, 1.6812225700000298, 0.9429690599999803, 0.5240810099999877, 0.5240810099999877, 
      0.5240810099999877, 0.2916748200000101, 1.0541158199999772]) 
y1 = [-0.749490900000005, -0.30380841000000913, -0.6113068699999573, -0.2937066899999863, 
      -0.2937066899999863, -1.2, -1.2, -0.37802362999996575, -0.20938560999999112, 
      -0.040836549999987426, 0.3354331199999834, -0.135405530000007, 0.07225013999997287, -0.04988554999999195, 
      -0.20938560999999112, 0.12579237000000631, -0.014561730000018258, -0.2937066899999863, 
      -0.2937066899999863, -0.2937066899999863, -0.09986690999999581, 0.005854710000001262]

plt.rcParams["font.weight"] = "bold"
plt.rcParams["font.size"] = 30
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams['lines.markersize'] = 15
plt.rc('lines', linewidth=10)
plt.rcParams['axes.linewidth'] = 3
fig = plt.figure(figsize=(12*1.618,12))
font=24

x2 = [-0.8,-0,1.8]
y2 = [-1.04545252, -0.56597409, 0.51285237]
y__ = [0,0,0]

plt.plot(x2,y2)
plt.plot(x2,x2,'--')
plt.plot(x2,y__,'--')
plt.xlabel('$\Delta E_{OH}$  (eV)', fontsize=40)
plt.ylabel('$\Delta E_{N_2}$  (eV)', fontsize=40)
plt.scatter(x1,y1, marker='D',c='black',zorder=2)
plt.xlim(-0.8,1.8)
plt.text(x1[2]+0.025, y1[2],'NbRuO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[10]+0.025, y1[10],'RuFeO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[6]+0.025,y1[6],'ReO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[1]-0.235,y1[1],'IrRuO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[20]-0.245, y1[20],'TiRuO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[7]-0.26,y1[7]-0.05,'ReRuO$_2$',fontsize=font,fontweight='bold')
#plt.text(x1[5],y1[5],'PtRuO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[11]-0.18,y1[11]-0.05,'RuO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[9]-0.12,y1[9]+0.05,'RhRuO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[0]+0.025, y1[0]-0.05,'IrO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[8]-0.07,y1[8]-0.15,'RhO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[4]+0.025,y1[4]-0.05,'PtO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[13]-0.13,y1[13]+0.05,'RuPtO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[16]-0.1,y1[16]-0.15,'TiPdO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[12]+0.025,y1[12],'RuPdO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[15]-0.03,y1[15]+0.05,'TiO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[21]+0.025,y1[21]-0.05,'dimer_TiPdO$_2$',fontsize=font,fontweight='bold')
plt.savefig('OHNN_0.pdf')

# %%
x1 = np.array([0.024024509999988286, 0.330519440000002, 0.11282755000000444, 0.5240810099999877, 
      0.5240810099999877, -0.7112466200000127, -0.7112466200000127, 0.1387598600000346, 0.787688150000021, 
      0.666470840000001, 1.0287009100000106, 0.6072369999999823, 0.9638732599999984, 0.41103776999999164, 
      0.787688150000021, 1.6812225700000298, 0.9429690599999803, 0.5240810099999877, 0.5240810099999877, 
      0.5240810099999877, 0.2916748200000101, 1.0541158199999772]) 
y1 = [-0.749490900000005, -0.30380841000000913, -0.6113068699999573, -0.2937066899999863, 
      -0.2937066899999863, -1.2, -1.2, -0.37802362999996575, -0.20938560999999112, 
      -0.040836549999987426, 0.3354331199999834, -0.135405530000007, 0.07225013999997287, -0.04988554999999195, 
      -0.20938560999999112, 0.12579237000000631, -0.014561730000018258, -0.2937066899999863, 
      -0.2937066899999863, -0.2937066899999863, -0.09986690999999581, 0.005854710000001262]

x3 = 0.09
y3 = -0.34

plt.rcParams["font.weight"] = "bold"
plt.rcParams["font.size"] = 30
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams['lines.markersize'] = 15
plt.rc('lines', linewidth=10)
plt.rcParams['axes.linewidth'] = 3
fig = plt.figure(figsize=(12*1.618,12))
font=24

x2 = [-0.8,-0,1.8]
y2 = [-1.04545252, -0.56597409, 0.51285237]
y__ = [0,0,0]

plt.plot(x2,y2)
plt.plot(x2,x2,'--')
plt.plot(x2,y__,'--')
plt.xlabel('$\Delta E_{OH}$  (eV)', fontsize=40)
plt.ylabel('$\Delta E_{N_2}$  (eV)', fontsize=40)
plt.scatter(x1,y1, marker='D',c='black',zorder=2)

plt.xlim(-0.8,1.8)
plt.text(x1[2]+0.025, y1[2],'NbRuO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[10]+0.025, y1[10],'RuFeO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[6]+0.025,y1[6],'ReO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[1]-0.235,y1[1],'IrRuO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[20]-0.245, y1[20],'TiRuO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[7]+0.03,y1[7]-0.05,'ReRuO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[11]-0.18,y1[11]-0.05,'RuO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[9]-0.12,y1[9]+0.05,'RhRuO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[0]+0.025, y1[0]-0.05,'IrO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[8]-0.07,y1[8]-0.15,'RhO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[4]+0.025,y1[4]-0.05,'PtO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[13]-0.13,y1[13]+0.05,'RuPtO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[16]-0.1,y1[16]-0.15,'TiPdO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[12]+0.025,y1[12],'RuPdO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[15]-0.03,y1[15]+0.05,'TiO$_2$',fontsize=font,fontweight='bold')
plt.text(x1[21]+0.025,y1[21]-0.05,'dimer_TiPdO$_2$',fontsize=font,fontweight='bold')
plt.scatter(x3,y3, marker='*',c='red', s=1000,zorder=3)
plt.text(x1[7]-0.46,y1[7],'Defect_IrO$_2$',fontsize=font,fontweight='bold', color = 'red')

plt.savefig('OHNN_0new.pdf')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

def func(x, a, b, c):
    return a + b*x - 0.5*c**2 * x**2

xdata = np.array([0.1, 0.2, 0.25, -0.1, -0.2, -0.25, 0.0])
y = np.array([-307.62073591, -307.65022274, -307.67388293, 
              -307.63329833, -307.67812627, -307.70813422, -307.6181924])

popt, pcov = curve_fit(func, xdata, y)
print(popt)
yfunc = -3.07616276e+02 + 6.84435548e-02*xdata - 0.5*1.54534867**2 * xdata**2
print(yfunc)
x_d = np.linspace(-0.25, 0.25, 50)
fig = plt.figure(figsize=(12*1.7,12))
plt.plot(x_d, func(x_d, *popt))
plt.scatter(xdata,y,marker='D',c='black')
plt.xlabel('Field(V/Angstrom)', fontsize=30)
plt.ylabel('Energy(eV)', fontsize=30)
plt.yticks([-307.7,-307.65,-307.6])
plt.ticklabel_format(useOffset=False)
plt.savefig('Efield_fs.pdf')
# Out:
# [-3.07616276e+02  6.84435548e-02  1.54534867e+00]
# [-307.62137216 -307.65034934 -307.67379331 -307.63506087 -307.67772676
#  -307.70801509 -307.616276  ]

# %%
y_ts = [-306.07771348, -306.11691056, -306.14602522,
        -306.08020979, -306.1164363, -306.14404104, -306.06928061]
popt_ts, pcov_ts = curve_fit(func, xdata, y_ts)
print(popt_ts)
fig = plt.figure(figsize=(12*1.7,12))
#plt.figure(figsize=[12,8])
plt.plot(x_d, func(x_d, *popt_ts))
plt.scatter(xdata,y_ts,marker='D',c='black')
plt.xlabel('Field(V/Angstrom)', fontsize=30)
plt.ylabel('Energy(eV)', fontsize=30)
plt.yticks([-306.05,-306.1,-306.15])
plt.savefig('Efield_ts.pdf')
# Out:
# [-3.06067538e+02 -1.50441717e-03  1.57154994e+00]

# %%
y_ts = [-306.07771348, -306.11691056, -306.14602522,
        -306.08020979, -306.1164363, -306.14404104, -306.06928061]
popt_ts, pcov_ts = curve_fit(func, xdata, y_ts)
print(popt_ts)
fig = plt.figure(figsize=(12*1.7,12))
#plt.figure(figsize=[12,8])
plt.plot(x_d, func(x_d, *popt_ts))
plt.scatter(xdata,y_ts,marker='D',c='black')
plt.xlabel('Field(V/Angstrom)', fontsize=30)
plt.ylabel('Energy(eV)', fontsize=30)
plt.yticks([-306.05,-306.1,-306.15])
plt.savefig('Efield_ts.pdf')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

def func(x, a, b, c):
    return a + b*x - 0.5*c**2 * x**2

xdata = np.array([-0.25,-0.2,-0.1,0.0,0.1,0.2,0.25])
y = np.array([-174.7930459,-174.60233227,-174.26927879,-174.00883455,-173.8311395,-173.7427074,-173.73528064])

popt, pcov = curve_fit(func, xdata, y)
print(popt)
yfunc = -3.07616276e+02 + 6.84435548e-02*xdata - 0.5*1.54534867**2 * xdata**2
print(yfunc)
x_d = np.linspace(-0.25, 0.25, 50)
fig = plt.figure(figsize=(12*1.7,12))
plt.plot(x_d, func(x_d, *popt))
plt.scatter(xdata,y,marker='D',c='black')
plt.xlabel('Field(V/Angstrom)', fontsize=30)
plt.ylabel('Energy(eV)', fontsize=30)
#plt.yticks([-307.7,-307.65,-307.6])
plt.ticklabel_format(useOffset=False)
plt.savefig('Efield1_fs.pdf')
